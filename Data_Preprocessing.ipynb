# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Load dataset
df = pd.read_csv("sorted_data.csv")

# Encode categorical column (example: Target)
le = LabelEncoder()
df['Target'] = le.fit_transform(df['Target'])

# Scale numeric data
scaler = StandardScaler()
num = df.select_dtypes(include='number')
df[num.columns] = scaler.fit_transform(num)

# Show output
print(df.head())
# Out:
#    Marital status  Application mode  Application order    Course  \
# 0       -0.294829         -0.095470           2.490896 -4.209520
# 1       -0.294829         -0.038271           3.252137  0.311805
# 2       -0.294829         -0.038271           2.490896  0.110674
# 3       -0.294829          1.448913          -0.554068  0.184826
# 4       -0.294829         -0.095470          -0.554068  0.394196
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                      0.350082                -0.35023
# 1                      0.350082                -0.35023
# 2                      0.350082                -0.35023
# 3                      0.350082                -0.35023
# 4                      0.350082                -0.35023
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                       -0.804841    -0.126298               -0.036018
# 1                        0.863489    -0.126298               -1.189759
# 2                       -0.880674    -0.126298               -0.933372
# 3                        1.318488    -0.126298               -1.189759
# 4                       -1.335673    -0.126298               -1.189759
#
#    Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 0               -0.669778  ...                            -0.282442
# 1               -1.386793  ...                            -0.282442
# 2               -1.256427  ...                            -0.282442
# 3                1.024985  ...                             0.760132
# 4               -1.386793  ...                            -0.282442
#
#    Curricular units 2nd sem (enrolled)  \
# 0                            -2.838337
# 1                             0.805144
# 2                            -0.561161
# 3                            -0.105726
# 4                            -0.105726
#
#    Curricular units 2nd sem (evaluations)  \
# 0                               -2.042630
# 1                                0.743941
# 2                               -0.776007
# 3                               -0.269358
# 4                                0.237291
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                            -1.471527                         -1.963489
# 1                             0.850642                          0.487738
# 2                            -1.471527                         -1.963489
# 3                             0.518904                          0.641283
# 4                             0.187165                          0.838697
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                       -0.199441          -0.287638
# 1                                       -0.199441           0.425695
# 2                                       -0.199441           0.425695
# 3                                       -0.199441           0.876222
# 4                                       -0.199441           0.313064
#
#    Inflation rate       GDP    Target
# 0        0.124386  0.765761 -1.326497
# 1        1.787974 -0.749872  0.925392
# 2        1.787974 -0.749872 -1.326497
# 3       -1.105222  0.347199  0.925392
# 4       -0.526582  0.787790 -0.200553
#
# [5 rows x 37 columns]
